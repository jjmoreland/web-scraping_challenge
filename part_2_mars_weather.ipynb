# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup as soup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
html = browser.html
mars_data = soup(html, 'html.parser')

# %%
# Extract all rows of data
table_rows = mars_data.find_all('tr', class_='data-row')

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
row_list = []
# Loop through the scraped data to create a list of rows
for row in table_rows: 
    row_data = row.find_all('td')
    id = row_data[0].text
    terrestrial_date = row_data[1].text
    sol = row_data[2].text
    ls = row_data[3].text
    month = row_data[4].text
    min_temp = row_data[5].text
    pressure = row_data[6].text
    
    row_dict={
        'id': id,
        'terrestrial_date': terrestrial_date,
        'sol': sol,
        'ls': ls,
        'month': month,
        'min_temp': min_temp, 
        'pressure': pressure
    }
    
    row_list.append(row_dict)

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
df = pd.DataFrame(row_list)

# %%
# Confirm DataFrame was created successfully
df.head()
# Out:
#    id terrestrial_date sol   ls month min_temp pressure
# 0   2       2012-08-16  10  155     6    -75.0    739.0
# 1  13       2012-08-17  11  156     6    -76.0    740.0
# 2  24       2012-08-18  12  156     6    -76.0    741.0
# 3  35       2012-08-19  13  157     6    -74.0    732.0
# 4  46       2012-08-20  14  157     6    -74.0    740.0

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
df. dtypes
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
# Change data types for data analysis
df['terrestrial_date']= pd.to_datetime(df['terrestrial_date'])
df = df.astype({'sol':'int64'})
df = df.astype({'ls':'int64'})
df = df.astype({'month':'int64'})
df = df.astype({'min_temp':'float64'})
df = df.astype({'pressure':'float64'})

# %%
# Confirm type changes were successful by examining data types again
df. dtypes
# Out:
# id                          object
# terrestrial_date    datetime64[ns]
# sol                          int64
# ls                           int64
# month                        int64
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
print(df['month'].value_counts().sort_index())
# Out:
# 1     174
# 2     178
# 3     192
# 4     194
# 5     149
# 6     147
# 7     142
# 8     141
# 9     134
# 10    112
# 11    138
# 12    166
# Name: month, dtype: int64

# %%
# 2. How many Martian days' worth of data are there?
day_count = len(df["sol"])
f"There are {day_count} Martian days worth of data in sample set"
# Out:
# 'There are 1867 Martian days worth of data in sample set'

# %%
# 3. What is the average low temperature by month?
min_temp_avg = df.groupby("month").mean()['min_temp']
#min_temp_avg = df.groupby("month").agg({"min_temp":"mean"})
min_temp_avg
# Out:
# C:\Users\justi\AppData\Local\Temp\ipykernel_18832\1647593301.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   min_temp_avg = df.groupby("month").mean()['min_temp']
# month
# 1    -77.160920
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# Name: min_temp, dtype: float64

# %%
# Plot the average temperature by month
# bar plot
min_temp_avg.plot(kind='bar',
        x='month',
        y='min_temp',
        color='lightblue')

# set the title
plt.title('Average Temperature By Month')
plt.xlabel('month')
plt.ylabel('Temperature (°C)')

# show the plot
plt.show()

# %%
# Identify the coldest and hottest months in Curiosity's location
cold_hot = df.groupby("month")
cold_hot["min_temp"].mean().sort_values()
# Out:
# month
# 3    -83.307292
# 4    -82.747423
# 2    -79.932584
# 5    -79.308725
# 1    -77.160920
# 6    -75.299320
# 12   -74.451807
# 7    -72.281690
# 11   -71.985507
# 10   -71.982143
# 9    -69.171642
# 8    -68.382979
# Name: min_temp, dtype: float64

# %%
print(f'As shown above, the coldest month observed by Curiosity rover is month 3 (-83.3072)')
print(f'As shown above, the hottest month observed by Curiosity rover is month 8 (-68.3829)')
# Out:
# As shown above, the coldest month observed by Curiosity rover is month 3 (-83.3072)
# As shown above, the hottest month observed by Curiosity rover is month 8 (-68.3829)

# %%
# 4. Average pressure by Martian month
pressure = df.groupby("month").mean()['pressure']
pressure
# Out:
# C:\Users\justi\AppData\Local\Temp\ipykernel_18832\108917497.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pressure = df.groupby("month").mean()['pressure']
# month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month
pressure.plot(kind='bar',
        x='month',
        y='pressure',
        color='blue')

# set the title
plt.title('Average Pressure by Month')
plt.xlabel('month')
plt.ylabel('Atmospheric Pressure')

# show the plot
plt.show()

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?
# Not stated explicitly, but use temperature readings over the time period (sols) 
# to indentify when temperatures peak/trough for a rough calculation.

df.plot( 'sol','min_temp', figsize=(20,10) )
plt.title('Martian days since Curiosity landed on Mars')
plt.xlabel('days')
plt.ylabel('Temperature (°C)')
#plt.grid(True, axis='x')
plt.xlim(0, 2000)
plt.minorticks_on()

# %%
print(f'Taking first peak to peak temperatures, 825-150, we get roughly 675 Martian days in a year')
print(f'Taking second peak to peak temperatures, 1480-825, we get roughly 650 Martian days in a year')  

print(f'The challenge provided context too that internet search will show that a Martian year is equivalent to 687 earth days')
# Out:
# Taking first peak to peak temperatures, 825-150, we get roughly 675 Martian days in a year
# Taking second peak to peak temperatures, 1480-825, we get roughly 650 Martian days in a year
# The challenge provided context too that internet search will show that a Martian year is equivalent to 687 earth days

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
df.to_csv('mars.csv')

# %%
browser.quit()
